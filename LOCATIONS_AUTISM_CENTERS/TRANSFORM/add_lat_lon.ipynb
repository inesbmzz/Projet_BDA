# %%
import pandas as pd

# %%
autism_center = pd.read_csv('autism_center.csv')

usa_lat_lon = pd.read_csv('usa_location.csv')

# %%
len(autism_center)
# Out:
# 674

# %%
merged_df = pd.merge(autism_center, usa_lat_lon, left_on='city', right_on='name', how='left')

# %%
len(merged_df)
# Out:
# 674

# %%
merged_df
# Out:
#                                                 name_x  country  \
# 0                         Center for Advanced Medicine  Germany
# 1                                          Kobinia Med  Austria
# 2                                  MexStemCells Clinic   Mexico
# 3    Immunotherapy Regenerative Medicine - Stem Cel...   Mexico
# 4                                    Bioscience Clinic      UAE
# ..                                                 ...      ...
# 669                 Child Development Center Region II      USA
# 670                             Magic City Enterprises      USA
# 671                          The Arc of Laramie County      USA
# 672                          The Arc of Natrona County      USA
# 673                                 The Arc of Wyoming      USA
#
#                 city                                         address  \
# 0          Frankfurt               ,lbeler Landstrasse, 45b,,60388,,
# ...

# %%
merged_df['latitude'] = merged_df['latitude_x'].fillna(merged_df['latitude_y'])
merged_df['longitude'] = merged_df['longitude_x'].fillna(merged_df['longitude_y'])

# %%
merged_df.drop(columns=['latitude_x','longitude_x','latitude_x','state','latitude_y','longitude_y','name_y'], inplace=True)

# %%
merged_df = merged_df.rename(columns={'name_x': 'name'})

# %%
desired_order = ['name', 'country', 'city', 'address', 'latitude', 'longitude', 'info', 'free_quote_link']
merged_df = merged_df.reindex(columns=desired_order)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 674 entries, 0 to 673
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             674 non-null    object
#  1   country          674 non-null    object
#  2   city             674 non-null    object
#  3   address          674 non-null    object
#  4   latitude         674 non-null    float64
#  5   longitude        674 non-null    float64
#  6   info             652 non-null    object
#  7   free_quote_link  13 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 42.2+ KB

# %%
merged_df.to_csv('clean_autism_center.csv', index=False)
